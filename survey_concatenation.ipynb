# %%
import pandas as pd

# %%
# import dataset
# !!! Each survey of the year should be imported separately for further usage. 
# It can be done by simply changing the year of the following line
df_2016 = pd.read_csv("./surveys/OSMI 2016 Mental Health Survey.csv")

# %%
# show all columns, hidden columns as well
pd.set_option('display.max_columns', 125)
df_2016.head(2)
# Out:
#    Are you self-employed?  \
# 0                       0
# 1                       0
#
#   How many employees does your company or organization have?  \
# 0                                             26-100
# 1                                               6-25
#
#    Is your employer primarily a tech company/organization?  \
# 0                                                1.0
# 1                                                1.0
#
#    Is your primary role within your company related to tech/IT?  \
# 0                                                NaN
# 1                                                NaN
#
#   Does your employer provide mental health benefits as part of healthcare coverage?  \
# 0                    Not eligible for coverage / N/A
# 1                                                 No
#
#   Do you know the options for mental health care available under your employer-provided coverage?  \
# 0                                                NaN
# ...

# %% [markdown]
# # 2021 survey

# %%
# select important columns
df_2021_selected_rows = df_2021[[
    'What is your age?',
    'What is your gender?',
    '*Are you self-employed?*',
    'What country do you *work* in?',
    'What country do you *live* in?',
    'Do you have a family history of mental illness?',
    'Do you *currently* have a mental health disorder?',
    'Have you had a mental health disorder in the past?',
    'How many employees does your company or organization have?',
    'Have your previous employers provided mental health benefits?',
    'Have you ever been *diagnosed* with a mental health disorder?',
    'Does your employer provide mental health benefits as part of healthcare coverage?',
    'Would you feel comfortable discussing a mental health issue with your coworkers?',
    'Have you ever sought treatment for a mental health disorder from a mental health professional?',    
    'Would you feel comfortable discussing a mental health issue with your direct supervisor(s)?',
    'Do you have medical coverage (private insurance or state-provided) that includes treatment of mental health disorders?',
]]

# %%
df_2021_selected_rows.head()
# Out:
#    What is your age? What is your gender?  *Are you self-employed?*  \
# 0                 28               Female                         0
# 1                 41                 male                         0
# 2                 35                 Male                         0
# 3                 20                 male                         1
# 4                 35               female                         0
#
#   What country do you *work* in? What country do you *live* in?  \
# 0       United States of America       United States of America
# 1                         Brazil                         Brazil
# 2                         Brazil                         Brazil
# 3                          Italy                          Italy
# 4                         Canada                         Canada
#
#   Do you have a family history of mental illness?  \
# 0                                    I don't know
# 1                                              No
# ...

# %%
print(df_2021_selected_rows['*Are you self-employed?*'].value_counts())
print(df_2021_selected_rows['How many employees does your company or organization have?'].value_counts())
print(df_2021_selected_rows['What country do you *live* in?'].value_counts())
print(df_2021_selected_rows['Do you have medical coverage (private insurance or state-provided) that includes treatment of mental health disorders?'].value_counts())
print(df_2021_selected_rows['Would you feel comfortable discussing a mental health issue with your coworkers?'].value_counts())
print(df_2021_selected_rows['Does your employer provide mental health benefits as part of healthcare coverage?'].value_counts())
print(df_2021_selected_rows['Have your previous employers provided mental health benefits?'].value_counts())
print(df_2021_selected_rows['Would you feel comfortable discussing a mental health issue with your direct supervisor(s)?'].value_counts())
print(df_2021_selected_rows['What country do you *work* in?'].value_counts())
# Out:
# 0    114
# 1     17
# Name: *Are you self-employed?*, dtype: int64
# More than 1000    48
# 100-500           22
# 26-100            20
# 6-25              11
# 500-1000           9
# 1-5                4
# Name: How many employees does your company or organization have?, dtype: int64
# United States of America    49
# India                       21
# Brazil                       8
# Germany                      7
# Slovenia                     6
# Macedonia                    5
# Italy                        3
# Australia                    2
# Netherlands                  2
# Indonesia                    2
# Israel                       2
# United Kingdom               2
# Canada                       2
# Greece                       1
# Bangladesh                   1
# Bulgaria                     1
# South Africa                 1
# Portugal                     1
# Colombia                     1
# Estonia                      1
# China                        1
# ...

# %% [markdown]
# # 2020 survey

# %%
df_2020_selected_rows = df_2020[[
    'What is your age?',
    'What is your gender?',
    '*Are you self-employed?*',
    'What country do you *work* in?',
    'What country do you *live* in?',
    'Do you have a family history of mental illness?',
    'Do you *currently* have a mental health disorder?',
    'Have you had a mental health disorder in the past?',
    'How many employees does your company or organization have?',
    'Have your previous employers provided mental health benefits?',
    'Have you ever been *diagnosed* with a mental health disorder?',
    'Does your employer provide mental health benefits as part of healthcare coverage?',
    'Would you feel comfortable discussing a mental health issue with your coworkers?',
    'Have you ever sought treatment for a mental health disorder from a mental health professional?',    
    'Would you feel comfortable discussing a mental health issue with your direct supervisor(s)?',
    'Do you have medical coverage (private insurance or state-provided) that includes treatment of mental health disorders?',
]]

# %%
df_2020_selected_rows.head(2)
# Out:
#    What is your age? What is your gender?  *Are you self-employed?*  \
# 0                 45                 Male                         1
# 1                 24               female                         1
#
#   What country do you *work* in? What country do you *live* in?  \
# 0       United States of America       United States of America
# 1                         Russia                         Russia
#
#   Do you have a family history of mental illness?  \
# 0                                             Yes
# 1                                             Yes
#
#   Do you *currently* have a mental health disorder?  \
# 0                                        Don't Know
# 1                                               Yes
#
#   Have you had a mental health disorder in the past?  \
# 0                                         Don't Know
# 1                                                Yes
#
#   How many employees does your company or organization have?  \
# ...

# %%
print(df_2020_selected_rows['*Are you self-employed?*'].value_counts())
print(df_2020_selected_rows['How many employees does your company or organization have?'].value_counts())
print(df_2020_selected_rows['What country do you *live* in?'].value_counts())
print(df_2020_selected_rows['Do you have medical coverage (private insurance or state-provided) that includes treatment of mental health disorders?'].value_counts())
print(df_2020_selected_rows['Would you feel comfortable discussing a mental health issue with your coworkers?'].value_counts())
print(df_2020_selected_rows['Does your employer provide mental health benefits as part of healthcare coverage?'].value_counts())
print(df_2020_selected_rows['Have your previous employers provided mental health benefits?'].value_counts())
print(df_2020_selected_rows['Would you feel comfortable discussing a mental health issue with your direct supervisor(s)?'].value_counts())
print(df_2020_selected_rows['What country do you *work* in?'].value_counts())
# Out:
# 0    155
# 1     25
# Name: *Are you self-employed?*, dtype: int64
# More than 1000    72
# 26-100            28
# 100-500           24
# 500-1000          20
# 6-25              10
# 1-5                1
# Name: How many employees does your company or organization have?, dtype: int64
# United States of America    65
# India                       33
# Canada                      11
# United Kingdom               7
# Brazil                       7
# Spain                        6
# Australia                    5
# Netherlands                  5
# Germany                      5
# Philippines                  3
# Ireland                      2
# Turkey                       2
# South Africa                 2
# Indonesia                    2
# Russia                       2
# Poland                       2
# Sri Lanka                    2
# France                       2
# Mongolia                     2
# Sweden                       2
# Egypt                        1
# ...

# %% [markdown]
# # 2019 survey

# %%
df_2019_selected_rows = df_2019[[
    'What is your age?',
    'What is your gender?',
    '*Are you self-employed?*',
    'What country do you *work* in?',
    'What country do you *live* in?',
    'Do you have a family history of mental illness?',
    'Do you *currently* have a mental health disorder?',
    'Have you had a mental health disorder in the past?',
    'How many employees does your company or organization have?',
    'Have your previous employers provided mental health benefits?',
    'Have you ever been *diagnosed* with a mental health disorder?',
    'Does your employer provide mental health benefits as part of healthcare coverage?',
    'Would you feel comfortable discussing a mental health issue with your coworkers?',
    'Have you ever sought treatment for a mental health disorder from a mental health professional?',    
    'Would you feel comfortable discussing a mental health issue with your direct supervisor(s)?',
    'Do you have medical coverage (private insurance or state-provided) that includes treatment of mental health disorders?',
 
]]

# %%
df_2019_selected_rows.head(2)
# Out:
#    What is your age? What is your gender?  *Are you self-employed?*  \
# 0                 25                 Male                     False
# 1                 51                 male                     False
#
#   What country do you *work* in? What country do you *live* in?  \
# 0       United States of America       United States of America
# 1       United States of America       United States of America
#
#   Do you have a family history of mental illness?  \
# 0                                              No
# 1                                             Yes
#
#   Do you *currently* have a mental health disorder?  \
# 0                                        Don't Know
# 1                                          Possibly
#
#   Have you had a mental health disorder in the past?  \
# 0                                                 No
# 1                                           Possibly
#
#   How many employees does your company or organization have?  \
# ...

# %%
print(df_2019_selected_rows['*Are you self-employed?*'].value_counts())
print(df_2019_selected_rows['How many employees does your company or organization have?'].value_counts())
print(df_2019_selected_rows['What country do you *live* in?'].value_counts())
print(df_2019_selected_rows['Do you have medical coverage (private insurance or state-provided) that includes treatment of mental health disorders?'].value_counts())
print(df_2019_selected_rows['Would you feel comfortable discussing a mental health issue with your coworkers?'].value_counts())
print(df_2019_selected_rows['Does your employer provide mental health benefits as part of healthcare coverage?'].value_counts())
print(df_2019_selected_rows['Have your previous employers provided mental health benefits?'].value_counts())
print(df_2019_selected_rows['Would you feel comfortable discussing a mental health issue with your direct supervisor(s)?'].value_counts())
print(df_2019_selected_rows['What country do you *work* in?'].value_counts())
# Out:
# False    304
# True      48
# Name: *Are you self-employed?*, dtype: int64
# More than 1000    111
# 100-500            80
# 26-100             45
# 6-25               34
# 500-1000           27
# 1-5                 7
# Name: How many employees does your company or organization have?, dtype: int64
# United States of America    204
# United Kingdom               32
# Portugal                     18
# Brazil                       17
# Canada                       15
# India                        13
# Norway                        5
# Netherlands                   4
# Germany                       4
# Switzerland                   4
# Spain                         3
# Poland                        3
# Turkey                        3
# Pakistan                      2
# Estonia                       2
# Belgium                       2
# Mexico                        2
# Italy                         2
# New Zealand                   2
# Ireland                       2
# ...

# %% [markdown]
# # 2018 survey

# %%
df_2018_selected_rows = df_2018[[
    'What is your age?',
    'What is your gender?', 
    '<strong>Are you self-employed?</strong>',
    'What country do you <strong>work</strong> in?',
    'What country do you <strong>live</strong> in?',
    'Do you have a family history of mental illness?',
    'Do you currently have a mental health disorder?',
    'Have you had a mental health disorder in the past?',
    'How many employees does your company or organization have?',
    '<strong>Have your previous employers provided mental health benefits?</strong>',
    'Have you ever been diagnosed with a mental health disorder?',
    'Does your employer provide mental health benefits as part of healthcare coverage?',
    'Would you feel comfortable discussing a mental health issue with your coworkers?',
    'Have you ever sought treatment for a mental health disorder from a mental health professional?',    
    'Would you feel comfortable discussing a mental health issue with your direct supervisor(s)?',
    'Do you have medical coverage (private insurance or state-provided) that includes treatment of mental health disorders?',

]]

# %%
df_2018_selected_rows.head(2)
# Out:
#    What is your age? What is your gender?  \
# 0                 57               Female
# 1                 29                 male
#
#    <strong>Are you self-employed?</strong>  \
# 0                                        0
# 1                                        0
#
#   What country do you <strong>work</strong> in?  \
# 0                                        Canada
# 1                      United States of America
#
#   What country do you <strong>live</strong> in?  \
# 0                                        Canada
# 1                      United States of America
#
#   Do you have a family history of mental illness?  \
# 0                                             Yes
# 1                                             Yes
#
#   Do you currently have a mental health disorder?  \
# 0                                        Possibly
# 1                                             Yes
#
#   Have you had a mental health disorder in the past?  \
# ...

# %%
print(df_2018_selected_rows['<strong>Are you self-employed?</strong>'].value_counts())
print(df_2018_selected_rows['How many employees does your company or organization have?'].value_counts())
print(df_2018_selected_rows['What country do you <strong>live</strong> in?'].value_counts())
print(df_2018_selected_rows['Do you have medical coverage (private insurance or state-provided) that includes treatment of mental health disorders?'].value_counts())
print(df_2018_selected_rows['Would you feel comfortable discussing a mental health issue with your coworkers?'].value_counts())
print(df_2018_selected_rows['Does your employer provide mental health benefits as part of healthcare coverage?'].value_counts())
print(df_2018_selected_rows['<strong>Have your previous employers provided mental health benefits?</strong>'].value_counts())
print(df_2018_selected_rows['Would you feel comfortable discussing a mental health issue with your direct supervisor(s)?'].value_counts())
print(df_2018_selected_rows['What country do you <strong>work</strong> in?'].value_counts())
# Out:
# 0    361
# 1     56
# Name: <strong>Are you self-employed?</strong>, dtype: int64
# More than 1000    105
# 100-500            81
# 26-100             70
# 6-25               69
# 500-1000           31
# 1-5                 5
# Name: How many employees does your company or organization have?, dtype: int64
# United States of America    312
# United Kingdom               19
# Canada                        8
# Germany                       7
# Poland                        6
# Netherlands                   5
# India                         5
# France                        4
# Australia                     4
# Italy                         4
# Ireland                       3
# Norway                        3
# Spain                         3
# Colombia                      2
# Finland                       2
# Japan                         2
# Mexico                        2
# Brazil                        2
# Serbia                        2
# Greece                        1
# ...

# %% [markdown]
# # 2017 survey

# %%
df_2017_selected_rows = df_2017[[
    'What is your age?',
    'What is your gender?',
    '<strong>Are you self-employed?</strong>',
    'What country do you <strong>work</strong> in?',
    'What country do you <strong>live</strong> in?',
    'Do you have a family history of mental illness?',
    'Do you currently have a mental health disorder?',
    'Have you had a mental health disorder in the past?',
    'How many employees does your company or organization have?',
    '<strong>Have your previous employers provided mental health benefits?</strong>',
    'Have you ever been diagnosed with a mental health disorder?',
    'Does your employer provide mental health benefits as part of healthcare coverage?',
    'Would you feel comfortable discussing a mental health issue with your coworkers?',
    'Have you ever sought treatment for a mental health disorder from a mental health professional?',    
    'Would you feel comfortable discussing a mental health issue with your direct supervisor(s)?',
    'Do you have medical coverage (private insurance or state-provided) that includes treatment of mental health disorders?',

]]

# %%
df_2017_selected_rows.head(2)
# Out:
#    What is your age? What is your gender?  \
# 0               27.0               Female
# 1               31.0                 male
#
#    <strong>Are you self-employed?</strong>  \
# 0                                        0
# 1                                        0
#
#   What country do you <strong>work</strong> in?  \
# 0                                United Kingdom
# 1                                United Kingdom
#
#   What country do you <strong>live</strong> in?  \
# 0                                United Kingdom
# 1                                United Kingdom
#
#   Do you have a family history of mental illness?  \
# 0                                              No
# 1                                              No
#
#   Do you currently have a mental health disorder?  \
# 0                                        Possibly
# 1                                        Possibly
#
#   Have you had a mental health disorder in the past?  \
# ...

# %%
print(df_2017_selected_rows['<strong>Are you self-employed?</strong>'].value_counts())
print(df_2017_selected_rows['How many employees does your company or organization have?'].value_counts())
print(df_2017_selected_rows['What country do you <strong>live</strong> in?'].value_counts())
print(df_2017_selected_rows['Do you have medical coverage (private insurance or state-provided) that includes treatment of mental health disorders?'].value_counts())
print(df_2017_selected_rows['Would you feel comfortable discussing a mental health issue with your coworkers?'].value_counts())
print(df_2017_selected_rows['Does your employer provide mental health benefits as part of healthcare coverage?'].value_counts())
print(df_2017_selected_rows['<strong>Have your previous employers provided mental health benefits?</strong>'].value_counts())
print(df_2017_selected_rows['Would you feel comfortable discussing a mental health issue with your direct supervisor(s)?'].value_counts())
print(df_2017_selected_rows['What country do you <strong>work</strong> in?'].value_counts())
# Out:
# 0    643
# 1    113
# Name: <strong>Are you self-employed?</strong>, dtype: int64
# 100-500           203
# More than 1000    158
# 26-100            128
# 6-25               86
# 500-1000           48
# 1-5                20
# Name: How many employees does your company or organization have?, dtype: int64
# United States of America    497
# United Kingdom               66
# Canada                       26
# Germany                      22
# France                       17
# Spain                        15
# Netherlands                  14
# India                        13
# Australia                    12
# Switzerland                   6
# New Zealand                   4
# Ireland                       4
# Romania                       4
# Argentina                     3
# Russia                        3
# Sweden                        3
# South Africa                  3
# Belgium                       3
# Japan                         3
# Mexico                        3
# ...

# %% [markdown]
# # 2016 survey

# %%
df_2016_selected_rows = df_2016[[
    'What is your age?',
    'What is your gender?', 
    'Are you self-employed?',
    'What country do you work in?',
    'What country do you live in?',
    'Do you have a family history of mental illness?',
    'Do you currently have a mental health disorder?',
    'Have you had a mental health disorder in the past?',
    'How many employees does your company or organization have?',
    'Have your previous employers provided mental health benefits?',
    'Have you been diagnosed with a mental health condition by a medical professional?',
    'Does your employer provide mental health benefits as part of healthcare coverage?',
    'Would you feel comfortable discussing a mental health disorder with your coworkers?',
    'Have you ever sought treatment for a mental health issue from a mental health professional?',
    'Would you feel comfortable discussing a mental health disorder with your direct supervisor(s)?',
    'Do you have medical coverage (private insurance or state-provided) which includes treatment of  mental health issues?',
]]

# %%
df_2016_selected_rows.head(2)
# Out:
#    What is your age? What is your gender?  Are you self-employed?  \
# 0                 39                 Male                       0
# 1                 29                 male                       0
#
#   What country do you work in? What country do you live in?  \
# 0               United Kingdom               United Kingdom
# 1     United States of America     United States of America
#
#   Do you have a family history of mental illness?  \
# 0                                              No
# 1                                             Yes
#
#   Do you currently have a mental health disorder?  \
# 0                                              No
# 1                                             Yes
#
#   Have you had a mental health disorder in the past?  \
# 0                                                Yes
# 1                                                Yes
#
#   How many employees does your company or organization have?  \
# ...

# %%
print(df_2016_selected_rows['Are you self-employed?'].value_counts())
print(df_2016_selected_rows['How many employees does your company or organization have?'].value_counts())
print(df_2016_selected_rows['What country do you live in?'].value_counts())
print(df_2016_selected_rows['Do you have medical coverage (private insurance or state-provided) which includes treatment of  mental health issues?'].value_counts())
print(df_2016_selected_rows['Would you feel comfortable discussing a mental health disorder with your coworkers?'].value_counts())
print(df_2016_selected_rows['Does your employer provide mental health benefits as part of healthcare coverage?'].value_counts())
print(df_2016_selected_rows['Have your previous employers provided mental health benefits?'].value_counts())
print(df_2016_selected_rows['Would you feel comfortable discussing a mental health disorder with your direct supervisor(s)?'].value_counts())
# Out:
# 0    1146
# 1     287
# Name: Are you self-employed?, dtype: int64
# 26-100            292
# More than 1000    256
# 100-500           248
# 6-25              210
# 500-1000           80
# 1-5                60
# Name: How many employees does your company or organization have?, dtype: int64
# United States of America    840
# United Kingdom              180
# Canada                       78
# Germany                      58
# Netherlands                  48
# Australia                    35
# Sweden                       19
# France                       16
# Ireland                      15
# Switzerland                  10
# Brazil                       10
# New Zealand                   9
# India                         9
# Russia                        9
# Bulgaria                      7
# Finland                       7
# Denmark                       7
# Italy                         5
# Belgium                       5
# South Africa                  4
# ...

# %% [markdown]
# # Renaming columns

# %% [markdown]
# ## 2016 selected columns

# %%
df_2016_selected_rows.rename(columns={
    'What is your age?': 'age',
    'What is your gender?': 'sex', 
    'Are you self-employed?': 'self-employed',
    'What country do you work in?': 'working_country',
    'What country do you live in?': 'living_country',
    'Do you have a family history of mental illness?': 'mental_illness_family_history',
    'Do you currently have a mental health disorder?': 'have_mental_illness',
    'Have you had a mental health disorder in the past?': 'mental_disorder_in_the_past',
    'How many employees does your company or organization have?': 'number_of_employees_your_company_has',
    'Have your previous employers provided mental health benefits?': 'mental_health_benefits_from_previous_employers',
    'Have you been diagnosed with a mental health condition by a medical professional?': 'mental_illness_diagnosis',
    'Does your employer provide mental health benefits as part of healthcare coverage?': 'mental_health_benefits_from_current_employer',
    'Would you feel comfortable discussing a mental health disorder with your coworkers?': 'discussing_mental_health_with_coworkers',
    'Have you ever sought treatment for a mental health issue from a mental health professional?': 'sought_mental_treatment',
    'Would you feel comfortable discussing a mental health disorder with your direct supervisor(s)?': 'discussing_mental_health_with_supervisor',
    'Do you have medical coverage (private insurance or state-provided) which includes treatment of  mental health issues?': 'mental_illness_medical_coverage',
}
    , inplace=True
)
# Out:
# <ipython-input-240-7b231b711f8b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2016_selected_rows.rename(columns={

# %%
df_2016_selected_rows.head(1)
# Out:
#    age   sex  self-employed working_country  living_country  \
# 0   39  Male              0  United Kingdom  United Kingdom
#
#   mental_illness_family_history have_mental_illness  \
# 0                            No                  No
#
#   mental_disorder_in_the_past number_of_employees_your_company_has  \
# 0                         Yes                               26-100
#
#   mental_health_benefits_from_previous_employers mental_illness_diagnosis  \
# 0                                   No, none did                      Yes
#
#   mental_health_benefits_from_current_employer  \
# 0              Not eligible for coverage / N/A
#
#   discussing_mental_health_with_coworkers  sought_mental_treatment  \
# 0                                   Maybe                        0
#
#   discussing_mental_health_with_supervisor  mental_illness_medical_coverage
# 0                                      Yes                              NaN

# %% [markdown]
# ## 2017 selected columns

# %%
df_2017_selected_rows.rename(columns={
    'What is your age?': 'age',
    'What is your gender?': 'sex',
    '<strong>Are you self-employed?</strong>': 'self-employed',
    'What country do you <strong>work</strong> in?': 'working_country',
    'What country do you <strong>live</strong> in?': 'living_country',
    'Do you have a family history of mental illness?': 'mental_illness_family_history',
    'Do you currently have a mental health disorder?': 'have_mental_illness',
    'Have you had a mental health disorder in the past?': 'mental_disorder_in_the_past',
    'How many employees does your company or organization have?': 'number_of_employees_your_company_has',
    '<strong>Have your previous employers provided mental health benefits?</strong>': 'mental_health_benefits_from_previous_employers',
    'Have you ever been diagnosed with a mental health disorder?': 'mental_illness_diagnosis',
    'Does your employer provide mental health benefits as part of healthcare coverage?': 'mental_health_benefits_from_current_employer',
    'Would you feel comfortable discussing a mental health issue with your coworkers?': 'discussing_mental_health_with_coworkers',
    'Have you ever sought treatment for a mental health disorder from a mental health professional?': 'sought_mental_treatment',    
    'Would you feel comfortable discussing a mental health issue with your direct supervisor(s)?': 'discussing_mental_health_with_supervisor',
    'Do you have medical coverage (private insurance or state-provided) that includes treatment of mental health disorders?': 'mental_illness_medical_coverage',
    }
    , inplace=True
)
# Out:
# <ipython-input-243-aa56b3c935d1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2017_selected_rows.rename(columns={

# %%
df_2017_selected_rows.head(2)
# Out:
#     age     sex  self-employed working_country  living_country  \
# 0  27.0  Female              0  United Kingdom  United Kingdom
# 1  31.0    male              0  United Kingdom  United Kingdom
#
#   mental_illness_family_history have_mental_illness  \
# 0                            No            Possibly
# 1                            No            Possibly
#
#   mental_disorder_in_the_past number_of_employees_your_company_has  \
# 0                    Possibly                              100-500
# 1                    Possibly                              100-500
#
#   mental_health_benefits_from_previous_employers mental_illness_diagnosis  \
# 0                                   I don't know                      NaN
# 1                                       Some did                      NaN
#
#   mental_health_benefits_from_current_employer  \
# 0                                           No
# 1                                          Yes
#
# ...

# %% [markdown]
# ## 2018 selected columns

# %%
df_2018_selected_rows.rename(columns={
    'What is your age?': 'age',
    'What is your gender?': 'sex', 
    '<strong>Are you self-employed?</strong>': 'self-employed',
    'What country do you <strong>work</strong> in?': 'working_country',
    'What country do you <strong>live</strong> in?': 'living_country',
    'Do you have a family history of mental illness?': 'mental_illness_family_history',
    'Do you currently have a mental health disorder?': 'have_mental_illness',
    'Have you had a mental health disorder in the past?': 'mental_disorder_in_the_past',
    'How many employees does your company or organization have?': 'number_of_employees_your_company_has',
    '<strong>Have your previous employers provided mental health benefits?</strong>': 'mental_health_benefits_from_previous_employers',
    'Have you ever been diagnosed with a mental health disorder?': 'mental_illness_diagnosis',
    'Does your employer provide mental health benefits as part of healthcare coverage?': 'mental_health_benefits_from_current_employer',
    'Would you feel comfortable discussing a mental health issue with your coworkers?': 'discussing_mental_health_with_coworkers',
    'Have you ever sought treatment for a mental health disorder from a mental health professional?': 'sought_mental_treatment',    
    'Would you feel comfortable discussing a mental health issue with your direct supervisor(s)?': 'discussing_mental_health_with_supervisor',
    'Do you have medical coverage (private insurance or state-provided) that includes treatment of mental health disorders?': 'mental_illness_medical_coverage',
    }
    , inplace=True
)
# Out:
# <ipython-input-245-207c3bd39f35>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018_selected_rows.rename(columns={

# %%
df_2018_selected_rows.head(2)
# Out:
#    age     sex  self-employed           working_country  \
# 0   57  Female              0                    Canada
# 1   29    male              0  United States of America
#
#              living_country mental_illness_family_history have_mental_illness  \
# 0                    Canada                           Yes            Possibly
# 1  United States of America                           Yes                 Yes
#
#   mental_disorder_in_the_past number_of_employees_your_company_has  \
# 0                         Yes                       More than 1000
# 1                         Yes                       More than 1000
#
#   mental_health_benefits_from_previous_employers mental_illness_diagnosis  \
# 0                                   No, none did                      NaN
# 1                                            NaN                      Yes
#
#   mental_health_benefits_from_current_employer  \
# 0                                          Yes
# ...

# %% [markdown]
# ## 2019 selected columns

# %%
df_2019_selected_rows.rename(columns={
    'What is your age?': 'age',
    'What is your gender?': 'sex',
    '*Are you self-employed?*': 'self-employed',
    'What country do you *work* in?': 'working_country',
    'What country do you *live* in?': 'living_country',
    'Do you have a family history of mental illness?': 'mental_illness_family_history',
    'Do you *currently* have a mental health disorder?': 'have_mental_illness',
    'Have you had a mental health disorder in the past?': 'mental_disorder_in_the_past',
    'How many employees does your company or organization have?': 'number_of_employees_your_company_has',
    'Have your previous employers provided mental health benefits?': 'mental_health_benefits_from_previous_employers',
    'Have you ever been *diagnosed* with a mental health disorder?': 'mental_illness_diagnosis',
    'Does your employer provide mental health benefits as part of healthcare coverage?': 'mental_health_benefits_from_current_employer',
    'Would you feel comfortable discussing a mental health issue with your coworkers?': 'discussing_mental_health_with_coworkers',
    'Have you ever sought treatment for a mental health disorder from a mental health professional?': 'sought_mental_treatment',    
    'Would you feel comfortable discussing a mental health issue with your direct supervisor(s)?': 'discussing_mental_health_with_supervisor',
    'Do you have medical coverage (private insurance or state-provided) that includes treatment of mental health disorders?': 'mental_illness_medical_coverage',
    }
    , inplace=True
)
# Out:
# <ipython-input-247-40445872777f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019_selected_rows.rename(columns={

# %%
df_2019_selected_rows.head(2)
# Out:
#    age   sex  self-employed           working_country  \
# 0   25  Male          False  United States of America
# 1   51  male          False  United States of America
#
#              living_country mental_illness_family_history have_mental_illness  \
# 0  United States of America                            No          Don't Know
# 1  United States of America                           Yes            Possibly
#
#   mental_disorder_in_the_past number_of_employees_your_company_has  \
# 0                          No                               26-100
# 1                    Possibly                               26-100
#
#   mental_health_benefits_from_previous_employers mental_illness_diagnosis  \
# 0                                   I don't know                      NaN
# 1                              Yes, they all did                      NaN
#
#   mental_health_benefits_from_current_employer  \
# 0                                 I don't know
# ...

# %% [markdown]
# ## 2020 selected columns

# %%
df_2020_selected_rows.rename(columns={
    'What is your age?': 'age',
    'What is your gender?': 'sex',
    '*Are you self-employed?*': 'self-employed',
    'What country do you *work* in?': 'working_country',
    'What country do you *live* in?': 'living_country',
    'Do you have a family history of mental illness?': 'mental_illness_family_history',
    'Do you *currently* have a mental health disorder?': 'have_mental_illness',
    'Have you had a mental health disorder in the past?': 'mental_disorder_in_the_past',
    'How many employees does your company or organization have?': 'number_of_employees_your_company_has',
    'Have your previous employers provided mental health benefits?': 'mental_health_benefits_from_previous_employers',
    'Have you ever been *diagnosed* with a mental health disorder?': 'mental_illness_diagnosis',
    'Does your employer provide mental health benefits as part of healthcare coverage?': 'mental_health_benefits_from_current_employer',
    'Would you feel comfortable discussing a mental health issue with your coworkers?': 'discussing_mental_health_with_coworkers',
    'Have you ever sought treatment for a mental health disorder from a mental health professional?': 'sought_mental_treatment',    
    'Would you feel comfortable discussing a mental health issue with your direct supervisor(s)?': 'discussing_mental_health_with_supervisor',
    'Do you have medical coverage (private insurance or state-provided) that includes treatment of mental health disorders?': 'mental_illness_medical_coverage',
    }
    , inplace=True
)
# Out:
# <ipython-input-249-4f21a5143b49>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020_selected_rows.rename(columns={

# %%
df_2020_selected_rows.head(2)
# Out:
#    age     sex  self-employed           working_country  \
# 0   45    Male              1  United States of America
# 1   24  female              1                    Russia
#
#              living_country mental_illness_family_history have_mental_illness  \
# 0  United States of America                           Yes          Don't Know
# 1                    Russia                           Yes                 Yes
#
#   mental_disorder_in_the_past number_of_employees_your_company_has  \
# 0                  Don't Know                                  NaN
# 1                         Yes                                  NaN
#
#   mental_health_benefits_from_previous_employers mental_illness_diagnosis  \
# 0                                   I don't know                      NaN
# 1                              Yes, they all did                      Yes
#
#   mental_health_benefits_from_current_employer  \
# 0                                          NaN
# ...

# %% [markdown]
# ## 2021 selected columns

# %%
df_2021_selected_rows.rename(columns={
    'What is your age?': 'age',
    'What is your gender?': 'sex',
    '*Are you self-employed?*': 'self-employed',
    'What country do you *work* in?': 'working_country',
    'What country do you *live* in?': 'living_country',
    'Do you have a family history of mental illness?': 'mental_illness_family_history',
    'Do you *currently* have a mental health disorder?': 'have_mental_illness',
    'Have you had a mental health disorder in the past?': 'mental_disorder_in_the_past',
    'How many employees does your company or organization have?': 'number_of_employees_your_company_has',
    'Have your previous employers provided mental health benefits?': 'mental_health_benefits_from_previous_employers',
    'Have you ever been *diagnosed* with a mental health disorder?': 'mental_illness_diagnosis',
    'Does your employer provide mental health benefits as part of healthcare coverage?': 'mental_health_benefits_from_current_employer',
    'Would you feel comfortable discussing a mental health issue with your coworkers?': 'discussing_mental_health_with_coworkers',
    'Have you ever sought treatment for a mental health disorder from a mental health professional?': 'sought_mental_treatment',    
    'Would you feel comfortable discussing a mental health issue with your direct supervisor(s)?': 'discussing_mental_health_with_supervisor',
    'Do you have medical coverage (private insurance or state-provided) that includes treatment of mental health disorders?': 'mental_illness_medical_coverage',
    }
    , inplace=True
)
# Out:
# <ipython-input-255-463d0dd256cc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2021_selected_rows.rename(columns={

# %%
df_2021_selected_rows.head(2)
# Out:
#    age     sex  self-employed           working_country  \
# 0   28  Female              0  United States of America
# 1   41    male              0                    Brazil
#
#              living_country mental_illness_family_history have_mental_illness  \
# 0  United States of America                  I don't know            Possibly
# 1                    Brazil                            No                  No
#
#   mental_disorder_in_the_past number_of_employees_your_company_has  \
# 0                    Possibly                               26-100
# 1                          No                             500-1000
#
#   mental_health_benefits_from_previous_employers mental_illness_diagnosis  \
# 0                                       Some did                      NaN
# 1                                       Some did                      NaN
#
#   mental_health_benefits_from_current_employer  \
# 0                                 I don't know
# ...

# %% [markdown]
# # Concatenating dataframes

# %% [markdown]
# ## All surveys 2016-2021

# %%
df_frames = [df_2016_selected_rows, df_2017_selected_rows, df_2018_selected_rows, 
             df_2019_selected_rows, df_2020_selected_rows, df_2021_selected_rows]

# %%
df_final = pd.concat(df_frames)

# %%
df_final.head(1)
# Out:
#     age   sex  self-employed working_country  living_country  \
# 0  39.0  Male              0  United Kingdom  United Kingdom
#
#   mental_illness_family_history have_mental_illness  \
# 0                            No                  No
#
#   mental_disorder_in_the_past number_of_employees_your_company_has  \
# 0                         Yes                               26-100
#
#   mental_health_benefits_from_previous_employers mental_illness_diagnosis  \
# 0                                   No, none did                      Yes
#
#   mental_health_benefits_from_current_employer  \
# 0              Not eligible for coverage / N/A
#
#   discussing_mental_health_with_coworkers  sought_mental_treatment  \
# 0                                   Maybe                        0
#
#   discussing_mental_health_with_supervisor mental_illness_medical_coverage
# 0                                      Yes                             NaN

# %%
print(df_final['age'].value_counts())
print(df_final['sex'].value_counts())
print(df_final['self-employed'].value_counts())
print(df_final['working_country'].value_counts())
print(df_final['living_country'].value_counts())
print(df_final['mental_illness_family_history'].value_counts())
print(df_final['have_mental_illness'].value_counts())
print(df_final['mental_disorder_in_the_past'].value_counts())
print(df_final['number_of_employees_your_company_has'].value_counts())
print(df_final['mental_health_benefits_from_previous_employers'].value_counts())
print(df_final['mental_illness_diagnosis'].value_counts())
print(df_final['mental_health_benefits_from_current_employer'].value_counts())
print(df_final['discussing_mental_health_with_coworkers'].value_counts())
print(df_final['sought_mental_treatment'].value_counts())
print(df_final['discussing_mental_health_with_supervisor'].value_counts())
print(df_final['mental_illness_medical_coverage'].value_counts())
# Out:
# 30.0     207
# 31.0     166
# 28.0     162
# 32.0     159
# 35.0     155
#         ...
# 15.0       1
# 17.0       1
# 323.0      1
# 99.0       1
# 223.0      1
# Name: age, Length: 62, dtype: int64
# Male                         1357
# male                          511
# Female                        437
# female                        241
# M                             152
#                              ...
# Female assigned at birth        1
# Transgender woman               1
# AFAB                            1
# cis man                         1
# Non-binary/Agender              1
# Name: sex, Length: 163, dtype: int64
# 0    2723
# 1     546
# Name: self-employed, dtype: int64
# United States of America    1988
# United Kingdom               309
# Canada                       135
# Germany                      103
# India                         92
#                             ...
# Ecuador                        1
# Swaziland                      1
# ...

# %%
df_final.to_csv("./combined_surveys_2016-2021/mental_health_data_2016-2021.csv")
